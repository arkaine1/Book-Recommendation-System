# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("books.csv")

# %%
df['subtitle'] = df['subtitle'].fillna("")
df['authors'] = df['authors'].fillna("Unknown")
df['categories'] = df['categories'].fillna("Unknown")
df['description'] = df['description'].fillna("Unknown")
df['thumbnail'] = df['thumbnail'].fillna("Unknown")

# %%
numerical_columns = ['published_year', 'average_rating', 'num_pages', 'ratings_count']
for col in numerical_columns:
    df[col] = df[col].fillna(df[col].median())

# %%
features = ['num_pages', 'ratings_count', 'published_year']
target = 'average_rating'

# %%
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Model Mean Squared Error: {mse}")
# Out:
# Model Mean Squared Error: 0.09216530768017864

# %%
def recommend_top_books(n=10):
    return df[['title', 'authors', 'average_rating', 'published_year']].sort_values(by='average_rating', ascending=False).head(n)

# %%
def find_books_by_author(author_name):
    return df[df['authors'].str.contains(author_name, case=False, na=False)][['title', 'authors', 'average_rating', 'published_year']]

# %%
def find_books_by_title(keyword):
    return df[df['title'].str.contains(keyword, case=False, na=False)][['title', 'authors', 'average_rating', 'published_year']]

# %%
def find_books_by_year(year):
    return df[df['published_year'] == year][['title', 'authors', 'average_rating', 'published_year']]

# %%
print("Top 5 Books:")
print(recommend_top_books(5))
# Out:
# Top 5 Books:
#                                 title                     authors  \
# 1441                Fanning the Flame    Christopher J. H. Wright
# 6738                         Insights              Frederick Lenz
# 4281                Middlesex Borough                     Unknown
# 4284                       Lake Orion  James E. Ingram;Lori Grove
# 5398  The Complete Theory Fun Factory    Katie Elliott;Ian Martin
#
#       average_rating  published_year
# 1441             5.0          2003.0
# 6738             5.0          2003.0
# 4281             5.0          2003.0
# 4284             5.0          2006.0
# 5398             5.0          1996.0

# %%
print("\nBooks by 'Agatha Christie':")
print(find_books_by_author("Agatha Christie"))
# Out:
# Books by 'Agatha Christie':
#                                              title  \
# 1                                     Spider's Web
# 6                                 An Autobiography
# 17    Witness for the Prosecution & Selected Plays
# 25                                     Miss Marple
# 40                               Partners in Crime
# 41                           Murder in Mesopotamia
# 44                             Death in the Clouds
# 45                          Appointment with Death
# 46                                Hallowe'en Party
# 47                      Hercule Poirot's Christmas
# 48                                    The Big Four
# 49                           The Thirteen Problems
# 50                         They Do it with Mirrors
# 51                           A Murder is Announced
# 52            The Mirror Crack'd from Side to Side
# 53                              Mrs McGinty's Dead
# 54                              Taken at the Flood
# 55                                      The Hollow
# 56                                      Third Girl
# 57                          The Secret of Chimneys
# 72                                   Endless Night
# 74                         The Mysterious Mr. Quin
# 75                          The Listerdale Mystery
# 88                                          Poirot
# 1492         Absent in the Spring and Other Novels
# 1611                                  Black Coffee
# 1620                                 Crooked House
# 2517                     Hercule Poirot's Casebook
# 2552         The Regatta Mystery and Other Stories
# 2619                  Murder on the Orient Express
# 6204                  Murder on the Orient Express
# 6205                            The A.B.C. Murders
# 6206                        Murder at the Vicarage
# 6207                       The Body in the Library
# 6208                   The Murder of Roger Ackroyd
# 6209                            Evil Under the Sun
# 6210                         A Murder is Announced
# 6211                             Death on the Nile
# 6212                 The Mystery of the Blue Train
#
#                               authors  average_rating  published_year
# 1     Charles Osborne;Agatha Christie            3.83          2000.0
# 6                     Agatha Christie            4.27          1977.0
# 17                    Agatha Christie            4.05          1995.0
# 25                    Agatha Christie            4.20          1997.0
# 40                    Agatha Christie            3.77          2001.0
# 41                    Agatha Christie            3.89          2001.0
# 44                    Agatha Christie            3.80          2001.0
# 45                    Agatha Christie            3.86          2001.0
# 46                    Agatha Christie            3.66          2001.0
# 47                    Agatha Christie            3.93          2001.0
# 48                    Agatha Christie            3.59          2002.0
# 49                    Agatha Christie            3.89          2002.0
# 50                    Agatha Christie            3.75          2002.0
# 51                    Agatha Christie            3.98          2002.0
# 52                    Agatha Christie            3.91          2002.0
# 53                    Agatha Christie            3.83          2002.0
# 54                    Agatha Christie            3.71          2002.0
# 55                    Agatha Christie            3.79          2002.0
# 56                    Agatha Christie            3.62          2002.0
# 57                    Agatha Christie            3.86          2001.0
# 72                    Agatha Christie            3.77          2002.0
# 74                    Agatha Christie            3.72          2003.0
# 75                    Agatha Christie            3.55          2003.0
# 88                    Agatha Christie            4.20          2005.0
# 1492  Mary Westmacott;Agatha Christie            4.19          2001.0
# 1611                  Agatha Christie            3.48          1999.0
# 1620                  Agatha Christie            4.02          2002.0
# 2517                  Agatha Christie            4.30          1989.0
# 2552                  Agatha Christie            3.95          1984.0
# 2619                  Agatha Christie            4.16          2004.0
# 6204                  Agatha Christie            4.16          1934.0
# 6205                  Agatha Christie            4.00          1936.0
# 6206                  Agatha Christie            4.05          2005.0
# 6207                  Agatha Christie            3.85          2006.0
# 6208                  Agatha Christie            4.23          1926.0
# 6209                  Agatha Christie            3.96          1940.0
# 6210                  Agatha Christie            3.98          2005.0
# 6211                  Agatha Christie            4.09          2007.0
# 6212                  Agatha Christie            3.80          1928.0

# %%
print("\nBooks with 'Harry Potter' in the title:")
print(find_books_by_title("Harry Potter"))
# Out:
# Books with 'Harry Potter' in the title:
#                                                   title  \
# 2661   Harry Potter and the Chamber of Secrets (Book 2)
# 2676  Harry Potter and the Order of the Phoenix (Boo...
# 2697            Harry Potter and the Chamber of Secrets
# 2698     Harry Potter and the Sorcerer's Stone (Book 1)
# 2710  Harry Potter and the Prisoner of Azkaban (Book 3)
# 2712                                       Harry Potter
# 2723    Harry Potter and the Half-Blood Prince (Book 6)
# 2730                        The Harry Potter Collection
# 4508                Harry Potter and the Goblet of Fire
# 4525           Harry Potter and the Prisoner of Azkaban
# 4599                        The Science of Harry Potter
# 5204                        Harry Potter and Philosophy
# 5330                   JK Rowling's Harry Potter Novels
# 5644  Ultimate Unofficial Guide to the Mysteries of ...
# 5660  Unauthorized Harry Potter and the Deathly Hall...
# 5871                    Looking for God in Harry Potter
# 6736                  Mapping the World of Harry Potter
#
#                                       authors  average_rating  published_year
# 2661                            Rowling, J.K.            4.41          2015.0
# 2676                            Rowling, J.K.            4.49          2015.0
# 2697              J. K. Rowling;Mary GrandPre            4.41          2003.0
# 2698                            Rowling, J.K.            4.47          2015.0
# 2710                            Rowling, J.K.            4.55          2015.0
# 2712                            J. K. Rowling            4.78          2004.0
# 2723                            Rowling, J.K.            4.56          2015.0
# 2730                            J. K. Rowling            4.73          2005.0
# 4508                            J. K. Rowling            4.55          2000.0
# 4525                            J. K. Rowling            4.55          2004.0
# 4599                          Roger Highfield            4.04          2002.0
# 5204  David Baggett;Shawn Klein;William Irwin            4.48          2004.0
# 5330                               Philip Nel            3.57          2001.0
# 5644        Galadriel Waters;Astre Mithrandir            4.05          2003.0
# 5660                   W. Frederick Zimmerman            3.69          2005.0
# 5871                             John Granger            4.13          2006.0
# 6736              Mercedes Lackey;Leah Wilson            4.32          2006.0

# %%
print("\nBooks published in 2005:")
print(find_books_by_year(2005))
# Out:
# Books published in 2005:
#                                                   title  \
# 71                                       The Family Way
# 88                                               Poirot
# 92                                          Naked Lunch
# 93                                     Tropic of Cancer
# 114                                   Diary of a Spider
# ...                                                 ...
# 6737                      Theory of Fun for Game Design
# 6741  There's No Toilet Paper... on the Road Less Tr...
# 6743                                         Hell House
# 6750                                        McSweeney's
# 6767                                       Underground!
#
#                         authors  average_rating  published_year
# 71                 Tony Parsons            3.51          2005.0
# 88              Agatha Christie            4.20          2005.0
# 92         William S. Burroughs            3.44          2005.0
# 93                 Henry Miller            3.69          2005.0
# 114               Doreen Cronin            4.25          2005.0
# ...                         ...             ...             ...
# 6737                Raph Koster            3.95          2005.0
# 6741                Doug Lansky            3.40          2005.0
# 6743  Ian Edginton;Simon Fraser            4.50          2005.0
# 6750                Dave Eggers            3.72          2005.0
# 6767               Preston Peet            3.84          2005.0
#
# [691 rows x 4 columns]
